# %% [markdown]
# <a href="https://colab.research.google.com/github/mostafasameer-transportation/Structural-Dynamics_Project/blob/mostafasameer-transportation/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt # Importing the pyplot module from matplotlib

# Define total_loading_time
total_loading_time = np.linspace(0, 10, 100)

# Define t_square and square_wave - these were not defined before
# Replace with your actual values
t_square = np.linspace(0, 10, 100) # Example: time values for the square wave
square_wave = np.sign(np.sin(2 * np.pi * t_square)) # Example: a simple square wave

# Adjusting the square wave to match the total loading time
square_wave_resampled = np.interp(total_loading_time, t_square, square_wave)

# You need to define harmonic_wave and triangular_wave as well
# Replace with your actual wave definitions
harmonic_wave = np.sin(2 * np.pi * total_loading_time) # Example: harmonic wave
triangular_wave = np.abs((total_loading_time % 2) - 1)  # Example: triangular wave

# Superposition of all waves
total_loading = harmonic_wave + triangular_wave + square_wave_resampled

# ... (Rest of your code) ... # Plotting, FFT calculation, etc.

# Assuming t_square and square_wave are already defined.
# Define total_loading_time
# For instance, let's say your total loading time is 10 seconds and
# You want to have 100 data points
total_loading_time = np.linspace(0, 10, 100)

# Adjusting the square wave to match the total loading time
square_wave_resampled = np.interp(total_loading_time, t_square, square_wave)

# Superposition of all waves
total_loading = harmonic_wave + triangular_wave + square_wave_resampled

# Adjusting the square wave to match the total loading time
square_wave_resampled = np.interp(total_loading_time, t_square, square_wave)

# Superposition of all waves
total_loading = harmonic_wave + triangular_wave + square_wave_resampled

# Plotting the waves
import matplotlib.pyplot as plt # Importing the pyplot module from matplotlib
plt.figure(figsize=(10, 6))
plt.plot(total_loading_time, total_loading, label='Total Loading')
plt.title('Superposition of Harmonic, Triangular, and Square Wave Loading')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude (kips)')
plt.grid(True)
plt.legend()
plt.show()

# FFT calculation
fft_result = np.fft.fft(total_loading)
fft_freq = np.fft.fftfreq(len(total_loading_time), total_loading_time[1] - total_loading_time[0])

# Plotting the FFT
plt.figure(figsize=(10, 6))
plt.plot(fft_freq[:len(fft_freq)//2], np.abs(fft_result)[:len(fft_result)//2])
plt.title('Frequency Spectrum of Total Loading')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()
